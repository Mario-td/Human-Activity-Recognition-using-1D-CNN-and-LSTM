# %%
import tensorflow as tf 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import time
import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

print(tf.__version__)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Label of the classes
LABELS = [    
    'JUMPING',
    'JUMPING_JACKS',
    'BOXING',
    'WAVING_2HANDS',
    'WAVING_1HAND',
    'CLAPPING_HANDS'
] 

# Dataset path
path = '/content/drive/My Drive/Colab Notebooks/RNN-HAR-2D-Pose-database/'

# Load the dataset
data = pd.read_csv(path + '/HAR.csv')

# %%
# Data visualization
data
# Out:
#         Label  Sequence     j0_x     j0_y  ...    j16_x    j16_y    j17_x    j17_y
# 0           0         0  295.914  161.579  ...    0.000    0.000  318.083  161.632
# 1           0         1  295.855  161.600  ...    0.000    0.000  318.024  161.654
# 2           0         2  293.296  161.620  ...    0.000    0.000  316.776  161.679
# 3           0         3  291.978  161.658  ...    0.000    0.000  316.720  161.697
# 4           0         4  288.063  168.120  ...    0.000    0.000  315.402  166.840
# ...       ...       ...      ...      ...  ...      ...      ...      ...      ...
# 908027      5        27  366.269  118.668  ...  340.189  119.987    0.000    0.000
# 908028      5        28  366.290  118.670  ...  340.209  119.993    0.000    0.000
# 908029      5        29  366.263  118.653  ...  340.198  119.966    0.000    0.000
# 908030      5        30  366.268  118.629  ...  340.203  119.970    0.000    0.000
# 908031      5        31  366.257  118.634  ...  340.208  119.964    0.000    0.000
#
# [908032 rows x 38 columns]

# %%
# Get the number of frames per sample
n_steps = max(data['Sequence']) + 1
n_steps
# Out:
# 32

# %%
# Get the labels
Y_ = np.array(data['Label'][0::n_steps][:], dtype=np.int32)
Y_.size
# Out:
# 28376

# %%
# Get the data
X_ = pd.DataFrame.to_numpy(data[data.columns[2:]])
# Split into the number of samples
X_ = np.array(np.split(X_, Y_.size))
X_.shape
# Out:
# (28376, 32, 36)

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_, Y_, test_size=0.2, random_state=42)

# %%
print('X_train shape '+ str(X_train.shape))
print('X_test shape '+ str(X_test.shape))
# Out:
# X_train shape (22700, 32, 36)
# X_test shape (5676, 32, 36)

# %%
# Hyperparameters and input data

# Number of input parameters per timestep
n_input = len(X_[0][0])

# Neurons in the hidden layer
n_hidden = 30 

n_classes = 6 

y_train = tf.keras.utils.to_categorical(y_train, n_classes)
y_test = tf.keras.utils.to_categorical(y_test, n_classes)

batch_size = 128 * n_steps
n_epochs = 100

# %%
# Exponential Decay Learning Rate
initial_learning_rate = 0.0011
decay_rate = 0.96 
decay_steps = 100 #250 * 6
decayed_lr = tf.keras.optimizers.schedules.ExponentialDecay(
              initial_learning_rate, decay_steps, decay_rate, staircase=True)

# %%
# reshape data into time steps of sub-sequences
n_sub_steps, n_length = 4, 8

X_train = tf.reshape(X_train,(X_train.shape[0], n_sub_steps, n_length, 36))
X_test = X_test.reshape((X_test.shape[0], n_sub_steps, n_length, 36))

# %%
# Define model
model = tf.keras.Sequential()
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None,n_length,36)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu')))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.5)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling1D(pool_size=2)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten()))
model.add(tf.keras.layers.LSTM(200))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dense(n_classes, activation='softmax'))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=decayed_lr, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss='categorical_crossentropy', optimizer= opt, metrics=['accuracy'])

t_start = time.time()

history = model.fit(X_train, y_train, shuffle=True, batch_size=batch_size, epochs=n_epochs)

t_stop = time.time() 
print( "Training time: " + str(datetime.timedelta(seconds= t_stop - t_start)))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 5s 763ms/step - loss: 1.8401 - accuracy: 0.2004
# Epoch 2/100
# 6/6 [==============================] - 4s 743ms/step - loss: 1.7740 - accuracy: 0.2169
# Epoch 3/100
# 6/6 [==============================] - 4s 727ms/step - loss: 1.7529 - accuracy: 0.2261
# Epoch 4/100
# 6/6 [==============================] - 4s 712ms/step - loss: 1.7434 - accuracy: 0.2307
# Epoch 5/100
# 6/6 [==============================] - 4s 714ms/step - loss: 1.7299 - accuracy: 0.2413
# Epoch 6/100
# 6/6 [==============================] - 4s 708ms/step - loss: 1.7087 - accuracy: 0.2574
# Epoch 7/100
# 6/6 [==============================] - 4s 709ms/step - loss: 1.6758 - accuracy: 0.2842
# Epoch 8/100
# 6/6 [==============================] - 4s 737ms/step - loss: 1.6218 - accuracy: 0.3163
# Epoch 9/100
# 6/6 [==============================] - 5s 771ms/step - loss: 1.5551 - accuracy: 0.3623
# Epoch 10/100
# 6/6 [==============================] - 5s 765ms/step - loss: 1.4460 - accuracy: 0.4192
# Epoch 11/100
# 6/6 [==============================] - 5s 762ms/step - loss: 1.3876 - accuracy: 0.4436
# Epoch 12/100
# 6/6 [==============================] - 4s 739ms/step - loss: 1.2376 - accuracy: 0.5161
# Epoch 13/100
# 6/6 [==============================] - 4s 717ms/step - loss: 1.1231 - accuracy: 0.5686
# Epoch 14/100
# 6/6 [==============================] - 4s 706ms/step - loss: 1.0045 - accuracy: 0.6052
# Epoch 15/100
# 6/6 [==============================] - 5s 763ms/step - loss: 0.8855 - accuracy: 0.6456
# Epoch 16/100
# 6/6 [==============================] - 5s 756ms/step - loss: 0.7831 - accuracy: 0.6789
# Epoch 17/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.7114 - accuracy: 0.7011
# Epoch 18/100
# 6/6 [==============================] - 6s 961ms/step - loss: 0.6576 - accuracy: 0.7171
# Epoch 19/100
# 6/6 [==============================] - 5s 763ms/step - loss: 0.6040 - accuracy: 0.7366
# Epoch 20/100
# 6/6 [==============================] - 5s 766ms/step - loss: 0.5705 - accuracy: 0.7535
# Epoch 21/100
# 6/6 [==============================] - 5s 765ms/step - loss: 0.5360 - accuracy: 0.7649
# Epoch 22/100
# 6/6 [==============================] - 5s 765ms/step - loss: 0.5154 - accuracy: 0.7743
# Epoch 23/100
# 6/6 [==============================] - 5s 769ms/step - loss: 0.4849 - accuracy: 0.7912
# Epoch 24/100
# 6/6 [==============================] - 5s 756ms/step - loss: 0.5450 - accuracy: 0.7658
# 6/6 [==============================] - 5s 751ms/step - loss: 0.1436 - accuracy: 0.9466
# Epoch 54/100
# 6/6 [==============================] - 5s 768ms/step - loss: 0.1363 - accuracy: 0.9504
# Epoch 55/100
# 6/6 [==============================] - 5s 764ms/step - loss: 0.1376 - accuracy: 0.9485
# Epoch 56/100
# 6/6 [==============================] - 5s 775ms/step - loss: 0.1570 - accuracy: 0.9441
# Epoch 57/100
# 6/6 [==============================] - 5s 764ms/step - loss: 0.1434 - accuracy: 0.9478
# Epoch 58/100
# 6/6 [==============================] - 5s 776ms/step - loss: 0.1309 - accuracy: 0.9515
# Epoch 59/100
# 6/6 [==============================] - 5s 771ms/step - loss: 0.1276 - accuracy: 0.9553
# Epoch 60/100
# 6/6 [==============================] - 5s 765ms/step - loss: 0.1246 - accuracy: 0.9548
# Epoch 61/100
# 6/6 [==============================] - 5s 765ms/step - loss: 0.1220 - accuracy: 0.9567
# Epoch 62/100
# 6/6 [==============================] - 5s 751ms/step - loss: 0.1185 - accuracy: 0.9578
# Epoch 63/100
# 6/6 [==============================] - 5s 763ms/step - loss: 0.1226 - accuracy: 0.9567
# Epoch 64/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.1098 - accuracy: 0.9598
# Epoch 65/100
# 6/6 [==============================] - 4s 741ms/step - loss: 0.1050 - accuracy: 0.9619
# Epoch 66/100
# 6/6 [==============================] - 5s 754ms/step - loss: 0.1200 - accuracy: 0.9574
# Epoch 67/100
# 6/6 [==============================] - 5s 755ms/step - loss: 0.1293 - accuracy: 0.9531
# Epoch 68/100
# 6/6 [==============================] - 5s 756ms/step - loss: 0.1179 - accuracy: 0.9571
# Epoch 69/100
# 6/6 [==============================] - 4s 744ms/step - loss: 0.1209 - accuracy: 0.9563
# Epoch 70/100
# 6/6 [==============================] - 5s 755ms/step - loss: 0.1046 - accuracy: 0.9630
# Epoch 71/100
# 6/6 [==============================] - 4s 718ms/step - loss: 0.0999 - accuracy: 0.9647
# Epoch 72/100
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0925 - accuracy: 0.9672
# Epoch 73/100
# 6/6 [==============================] - 4s 717ms/step - loss: 0.0918 - accuracy: 0.9667
# Epoch 74/100
# 6/6 [==============================] - 5s 773ms/step - loss: 0.0847 - accuracy: 0.9694
# Epoch 75/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0759 - accuracy: 0.9740
# Epoch 76/100
# 6/6 [==============================] - 5s 759ms/step - loss: 0.0814 - accuracy: 0.9711
# Epoch 77/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0722 - accuracy: 0.9750
# Epoch 78/100
# 6/6 [==============================] - 5s 762ms/step - loss: 0.0766 - accuracy: 0.9737
# Epoch 79/100
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0999 - accuracy: 0.9633
# Epoch 80/100
# 6/6 [==============================] - 5s 751ms/step - loss: 0.0883 - accuracy: 0.9673
# Epoch 81/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0793 - accuracy: 0.9738
# Epoch 82/100
# 6/6 [==============================] - 4s 747ms/step - loss: 0.0825 - accuracy: 0.9706
# Epoch 83/100
# 6/6 [==============================] - 5s 754ms/step - loss: 0.0803 - accuracy: 0.9718
# Epoch 84/100
# 6/6 [==============================] - 5s 752ms/step - loss: 0.0711 - accuracy: 0.9748
# Epoch 85/100
# 6/6 [==============================] - 5s 752ms/step - loss: 0.0707 - accuracy: 0.9750
# Epoch 86/100
# 6/6 [==============================] - 5s 755ms/step - loss: 0.0685 - accuracy: 0.9767
# Epoch 87/100
# 6/6 [==============================] - 5s 759ms/step - loss: 0.0730 - accuracy: 0.9742
# Epoch 88/100
# 6/6 [==============================] - 5s 769ms/step - loss: 0.0761 - accuracy: 0.9734
# Epoch 89/100
# 6/6 [==============================] - 5s 764ms/step - loss: 0.0870 - accuracy: 0.9693
# Epoch 90/100
# 6/6 [==============================] - 5s 755ms/step - loss: 0.0913 - accuracy: 0.9682
# Epoch 91/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0798 - accuracy: 0.9732
# Epoch 92/100
# 6/6 [==============================] - 5s 760ms/step - loss: 0.0692 - accuracy: 0.9759
# Epoch 93/100
# 6/6 [==============================] - 5s 759ms/step - loss: 0.0608 - accuracy: 0.9793
# Epoch 94/100
# 6/6 [==============================] - 5s 756ms/step - loss: 0.0642 - accuracy: 0.9757
# Epoch 95/100
# 6/6 [==============================] - 5s 758ms/step - loss: 0.0619 - accuracy: 0.9784
# Epoch 96/100
# 6/6 [==============================] - 5s 754ms/step - loss: 0.0957 - accuracy: 0.9667
# Epoch 97/100
# 6/6 [==============================] - 5s 757ms/step - loss: 0.0937 - accuracy: 0.9675
# Epoch 98/100
# 6/6 [==============================] - 5s 753ms/step - loss: 0.0776 - accuracy: 0.9730
# Epoch 99/100
# 6/6 [==============================] - 5s 752ms/step - loss: 0.0599 - accuracy: 0.9796
# Epoch 100/100
# 6/6 [==============================] - 5s 751ms/step - loss: 0.0533 - accuracy: 0.9811
# Training time: 0:09:14.030382

# %%
# Summarize history for accuracy
plt.plot(history.history['accuracy']) 
plt.title('model accuracy') 
plt.ylabel('accuracy') 
plt.xlabel('epoch') 
plt.legend(['train'], loc='upper left') 
plt.show()

# Summarize history for loss
plt.plot(history.history['loss']) 
plt.title('model loss') 
plt.ylabel('loss') 
plt.xlabel('epoch') 
plt.legend(['train'], loc='upper left') 
plt.show()

# %%
# Test accuracy
model.evaluate(X_test, y_test)
# Out:
# 178/178 [==============================] - 1s 6ms/step - loss: 0.0236 - accuracy: 0.9930
# [0.023565083742141724, 0.9929527640342712]

# %%
predicted_classes = model.predict_classes(X_test) 

# Sets the actual test label with the same format
y_test = y_test.argmax(1)

# %%
cm = confusion_matrix(predicted_classes, y_test)
plt.figure(figsize = (13, 8))
sns.heatmap(cm, annot = True, xticklabels = LABELS, yticklabels = LABELS)
