# %%
import tensorflow as tf 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import time
import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

print(tf.__version__)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Label of the classes
LABELS = [    
    'JUMPING',
    'JUMPING_JACKS',
    'BOXING',
    'WAVING_2HANDS',
    'WAVING_1HAND',
    'CLAPPING_HANDS'
] 

# Dataset path
path = '/content/drive/My Drive/Colab Notebooks/RNN-HAR-2D-Pose-database/'

# Load the dataset
data = pd.read_csv(path + '/HAR.csv')

# %%
# Data visualization
data
# Out:
#         Label  Sequence     j0_x     j0_y  ...    j16_x    j16_y    j17_x    j17_y
# 0           0         0  295.914  161.579  ...    0.000    0.000  318.083  161.632
# 1           0         1  295.855  161.600  ...    0.000    0.000  318.024  161.654
# 2           0         2  293.296  161.620  ...    0.000    0.000  316.776  161.679
# 3           0         3  291.978  161.658  ...    0.000    0.000  316.720  161.697
# 4           0         4  288.063  168.120  ...    0.000    0.000  315.402  166.840
# ...       ...       ...      ...      ...  ...      ...      ...      ...      ...
# 908027      5        27  366.269  118.668  ...  340.189  119.987    0.000    0.000
# 908028      5        28  366.290  118.670  ...  340.209  119.993    0.000    0.000
# 908029      5        29  366.263  118.653  ...  340.198  119.966    0.000    0.000
# 908030      5        30  366.268  118.629  ...  340.203  119.970    0.000    0.000
# 908031      5        31  366.257  118.634  ...  340.208  119.964    0.000    0.000
#
# [908032 rows x 38 columns]

# %%
# Get the number of frames per sample
n_steps = max(data['Sequence']) + 1
n_steps
# Out:
# 32

# %%
# Get the labels
Y_ = np.array(data['Label'][0::n_steps][:], dtype=np.int32)
Y_.size
# Out:
# 28376

# %%
# Get the data
X_ = pd.DataFrame.to_numpy(data[data.columns[2:]])
# Split into the number of samples
X_ = np.array(np.split(X_, Y_.size))
X_.shape
# Out:
# (28376, 32, 36)

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_, Y_, test_size=0.2) #, random_state=2

# %%
print('X_train shape '+ str(X_train.shape))
print('X_test shape '+ str(X_test.shape))
# Out:
# X_train shape (22700, 32, 36)
# X_test shape (5676, 32, 36)

# %%
# Hyperparameters and input data

# Number of input parameters per timestep
n_input = len(X_[0][0])

# Number of features
n_feat = X_.shape[2]

n_classes = 6 

y_train = tf.keras.utils.to_categorical(y_train, n_classes)
y_test = tf.keras.utils.to_categorical(y_test, n_classes)

batch_size = 128 * n_steps
n_epochs = 120

# %%
# Exponential Decay Learning Rate
initial_learning_rate = 0.002
decay_rate = 0.95
decay_steps = 100 
decayed_lr = tf.keras.optimizers.schedules.ExponentialDecay(
              initial_learning_rate, decay_steps, decay_rate, staircase=False)

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
  
  def on_epoch_begin(self, epoch, logs=None):
    lr = self.model.optimizer._decayed_lr('float32').numpy()
    print('\nLearning rate: {}'.format(lr))

# %%
# reshape data into time steps of sub-sequences
n_sub_steps, n_length = 4, 8

X_train = tf.reshape(X_train,(X_train.shape[0], n_sub_steps, n_length, n_feat))
X_test = X_test.reshape((X_test.shape[0], n_sub_steps, n_length, n_feat))

# %%
# Define model
model = tf.keras.Sequential()
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None,n_length,n_feat)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu')))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling1D(pool_size=2)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten()))
model.add(tf.keras.layers.LSTM(100))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dense(n_classes, activation='softmax'))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=decayed_lr, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss='categorical_crossentropy', optimizer= opt, metrics=['accuracy'])

t_start = time.time()

history = model.fit(X_train, y_train, shuffle=True, batch_size=batch_size, epochs=n_epochs, callbacks=[MyCustomCallback()])

t_stop = time.time() 
print( "Training time: " + str(datetime.timedelta(seconds= t_stop - t_start)))
# Out:
# Learning rate: 0.0020000000949949026
# Epoch 1/120
# 6/6 [==============================] - 3s 431ms/step - loss: 1.7906 - accuracy: 0.1958
#
# Learning rate: 0.001993854297325015
# Epoch 2/120
# 6/6 [==============================] - 3s 437ms/step - loss: 1.7410 - accuracy: 0.2285
#
# Learning rate: 0.001987727591767907
# Epoch 3/120
# 6/6 [==============================] - 3s 431ms/step - loss: 1.7387 - accuracy: 0.2294
#
# Learning rate: 0.0019816195126622915
# Epoch 4/120
# 6/6 [==============================] - 3s 431ms/step - loss: 1.7313 - accuracy: 0.2377
#
# Learning rate: 0.001975530292838812
# Epoch 5/120
# 6/6 [==============================] - 3s 432ms/step - loss: 1.7151 - accuracy: 0.2652
#
# Learning rate: 0.0019694596994668245
# Epoch 6/120
# 6/6 [==============================] - 3s 435ms/step - loss: 1.7086 - accuracy: 0.2805
#
# Learning rate: 0.0019634077325463295
# Epoch 7/120
# 6/6 [==============================] - 3s 434ms/step - loss: 1.6898 - accuracy: 0.3056
#
# Learning rate: 0.0019573746249079704
# Epoch 8/120
# 6/6 [==============================] - 3s 433ms/step - loss: 1.6436 - accuracy: 0.3407
#
# Learning rate: 0.0019513596780598164
# Epoch 9/120
# 6/6 [==============================] - 3s 436ms/step - loss: 1.5949 - accuracy: 0.3672
#
# Learning rate: 0.0019453634740784764
# Epoch 10/120
# 6/6 [==============================] - 3s 434ms/step - loss: 1.5965 - accuracy: 0.3609
#
# Learning rate: 0.0019393856637179852
# Epoch 11/120
# 6/6 [==============================] - 3s 433ms/step - loss: 1.5572 - accuracy: 0.3690
#
# Learning rate: 0.0019334261305630207
# Epoch 12/120
# 6/6 [==============================] - 3s 437ms/step - loss: 1.4744 - accuracy: 0.4043
#
# Learning rate: 0.001927484991028905
# Epoch 13/120
# 6/6 [==============================] - 3s 432ms/step - loss: 1.3933 - accuracy: 0.4406
#
# Learning rate: 0.0019215620122849941
# Epoch 14/120
# 6/6 [==============================] - 3s 434ms/step - loss: 1.2729 - accuracy: 0.4970
#
# Learning rate: 0.001915657427161932
# Epoch 15/120
# 6/6 [==============================] - 3s 437ms/step - loss: 1.1742 - accuracy: 0.5433
#
# Learning rate: 0.0019097707699984312
# Epoch 16/120
# 6/6 [==============================] - 3s 434ms/step - loss: 1.1170 - accuracy: 0.5585
#
# Learning rate: 0.0019039023900404572
# Epoch 17/120
# 6/6 [==============================] - 3s 432ms/step - loss: 0.9493 - accuracy: 0.6200
#
# Learning rate: 0.0018980519380420446
# Epoch 18/120
# 6/6 [==============================] - 3s 432ms/step - loss: 0.7982 - accuracy: 0.6794
#
# Learning rate: 0.0018922194140031934
# Epoch 19/120
# 6/6 [==============================] - 3s 444ms/step - loss: 0.7015 - accuracy: 0.7077
#
# Learning rate: 0.0018864049343392253
# Epoch 20/120
# 6/6 [==============================] - 3s 431ms/step - loss: 0.6278 - accuracy: 0.7320
#
# Learning rate: 0.0018806082662194967
# Epoch 21/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.5493 - accuracy: 0.7624
#
# Learning rate: 0.0018748294096440077
# Epoch 22/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.5204 - accuracy: 0.7770
#
# Learning rate: 0.0018690682481974363
# Epoch 23/120
# 6/6 [==============================] - 3s 433ms/step - loss: 0.5116 - accuracy: 0.7808
#
# Learning rate: 0.0018633248982951045
# Epoch 24/120
# 6/6 [==============================] - 3s 430ms/step - loss: 0.4901 - accuracy: 0.7881
#
# Learning rate: 0.0018575991271063685
# Epoch 25/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.4137 - accuracy: 0.8235
#
# Learning rate: 0.0018518910510465503
# Epoch 26/120
# 6/6 [==============================] - 3s 431ms/step - loss: 0.4061 - accuracy: 0.8268
#
# Learning rate: 0.0018462003208696842
# Epoch 27/120
# 6/6 [==============================] - 3s 431ms/step - loss: 0.3983 - accuracy: 0.8331
#
# Learning rate: 0.0018405272858217359
# Epoch 28/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.3815 - accuracy: 0.8420
#
# Learning rate: 0.0018348714802414179
# Epoch 29/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.3525 - accuracy: 0.8560
#
# Learning rate: 0.0018292332533746958
# Epoch 30/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.3340 - accuracy: 0.8615
#
# Learning rate: 0.0018236121395602822
# Epoch 31/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.3144 - accuracy: 0.8697
#
# Learning rate: 0.0018180084880441427
# Epoch 32/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.2941 - accuracy: 0.8820
#
# Learning rate: 0.0018124219495803118
# Epoch 33/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.2725 - accuracy: 0.8904
#
# Learning rate: 0.0018068526405841112
# Epoch 34/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.3153 - accuracy: 0.8717
#
# Learning rate: 0.0018013004446402192
# Epoch 35/120
# 6/6 [==============================] - 3s 433ms/step - loss: 0.3158 - accuracy: 0.8726
#
# Learning rate: 0.0017957653617486358
# Epoch 36/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.2709 - accuracy: 0.8938
#
# Learning rate: 0.0017902471590787172
# Epoch 37/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.2462 - accuracy: 0.9028
#
# Learning rate: 0.0017847460694611073
# Epoch 38/120
# 6/6 [==============================] - 3s 510ms/step - loss: 0.2281 - accuracy: 0.9146
#
# Learning rate: 0.0017792616272345185
# Epoch 39/120
# 6/6 [==============================] - 5s 757ms/step - loss: 0.2532 - accuracy: 0.9017
#
# Learning rate: 0.0017737942980602384
# Epoch 40/120
# 6/6 [==============================] - 3s 515ms/step - loss: 0.2228 - accuracy: 0.9159
#
# Learning rate: 0.0017683436162769794
# Epoch 41/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.2004 - accuracy: 0.9264
#
# Learning rate: 0.0017629096983000636
# Epoch 42/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.1819 - accuracy: 0.9344
#
# Learning rate: 0.0017574925441294909
# Epoch 43/120
# 6/6 [==============================] - 3s 442ms/step - loss: 0.1619 - accuracy: 0.9407
#
# Learning rate: 0.0017520919209346175
# Epoch 44/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.1526 - accuracy: 0.9457
#
# Learning rate: 0.0017467079451307654
# Epoch 45/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.1371 - accuracy: 0.9521
#
# Learning rate: 0.0017413406167179346
# Epoch 46/120
# 6/6 [==============================] - 3s 444ms/step - loss: 0.1362 - accuracy: 0.9509
#
# Learning rate: 0.0017359898192808032
# Epoch 47/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.1236 - accuracy: 0.9551
#
# Learning rate: 0.0017306553199887276
# Epoch 48/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.1344 - accuracy: 0.9514
#
# Learning rate: 0.0017253372352570295
# Epoch 49/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.2336 - accuracy: 0.9168
#
# Learning rate: 0.0017200354486703873
# Epoch 50/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.3748 - accuracy: 0.8611
#
# Learning rate: 0.0017147499602288008
# Epoch 51/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.2957 - accuracy: 0.8848
#
# Learning rate: 0.0017094808863475919
# Epoch 52/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.3007 - accuracy: 0.8894
#
# Learning rate: 0.0017042277613654733
# Epoch 53/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.2243 - accuracy: 0.9180
#
# Learning rate: 0.0016989909345284104
# Epoch 54/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.1930 - accuracy: 0.9280
#
# Learning rate: 0.0016937701730057597
# Epoch 55/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.1631 - accuracy: 0.9414
#
# Learning rate: 0.0016885654767975211
# Epoch 56/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.1410 - accuracy: 0.9488
#
# Learning rate: 0.0016833767294883728
# Epoch 57/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.1339 - accuracy: 0.9501
#
# Learning rate: 0.0016782039310783148
# Epoch 58/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.1224 - accuracy: 0.9550
#
# Learning rate: 0.001673047081567347
# Epoch 59/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.1161 - accuracy: 0.9578
#
# Learning rate: 0.001667905948124826
# Epoch 60/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.1235 - accuracy: 0.9546
#
# Learning rate: 0.0016627807635813951
# Epoch 61/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.1293 - accuracy: 0.9541
#
# Learning rate: 0.0016576711786910892
# Epoch 62/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.1130 - accuracy: 0.9602
#
# Learning rate: 0.0016525773098692298
# Epoch 63/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0952 - accuracy: 0.9669
#
# Learning rate: 0.001647499273531139
# Epoch 64/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.1050 - accuracy: 0.9614
#
# Learning rate: 0.001642436720430851
# Epoch 65/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.1015 - accuracy: 0.9642
#
# Learning rate: 0.0016373897669836879
# Epoch 66/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0812 - accuracy: 0.9729
#
# Learning rate: 0.0016323582967743278
# Epoch 67/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0767 - accuracy: 0.9741
#
# Learning rate: 0.0016273421933874488
# Epoch 68/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0729 - accuracy: 0.9748
#
# Learning rate: 0.0016223415732383728
# Epoch 69/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0713 - accuracy: 0.9751
#
# Learning rate: 0.001617356319911778
# Epoch 70/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0711 - accuracy: 0.9744
#
# Learning rate: 0.0016123864334076643
# Epoch 71/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0749 - accuracy: 0.9740
#
# Learning rate: 0.0016074316808953881
# Epoch 72/120
# 6/6 [==============================] - 3s 443ms/step - loss: 0.0788 - accuracy: 0.9714
#
# Learning rate: 0.0016024922952055931
# Epoch 73/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0656 - accuracy: 0.9764
#
# Learning rate: 0.0015975681599229574
# Epoch 74/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0605 - accuracy: 0.9792
#
# Learning rate: 0.0015926589258015156
# Epoch 75/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0588 - accuracy: 0.9804
#
# Learning rate: 0.001587764942087233
# Epoch 76/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0657 - accuracy: 0.9778
#
# Learning rate: 0.0015828859759494662
# Epoch 77/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0806 - accuracy: 0.9711
#
# Learning rate: 0.0015780219109728932
# Epoch 78/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0752 - accuracy: 0.9730
#
# Learning rate: 0.001573172863572836
# Epoch 79/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0712 - accuracy: 0.9748
#
# Learning rate: 0.0015683388337492943
# Epoch 80/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0684 - accuracy: 0.9767
#
# Learning rate: 0.0015635194722563028
# Epoch 81/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0703 - accuracy: 0.9743
#
# Learning rate: 0.0015587148955091834
# Epoch 82/120
# 6/6 [==============================] - 3s 433ms/step - loss: 0.0750 - accuracy: 0.9730
#
# Learning rate: 0.0015539252199232578
# Epoch 83/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0583 - accuracy: 0.9793
#
# Learning rate: 0.0015491503290832043
# Epoch 84/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0538 - accuracy: 0.9814
#
# Learning rate: 0.0015443898737430573
# Epoch 85/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0528 - accuracy: 0.9812
#
# Learning rate: 0.0015396442031487823
# Epoch 86/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0535 - accuracy: 0.9814
#
# Learning rate: 0.0015349130844697356
# Epoch 87/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0445 - accuracy: 0.9847
#
# Learning rate: 0.0015301965177059174
# Epoch 88/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0436 - accuracy: 0.9849
#
# Learning rate: 0.0015254943864420056
# Epoch 89/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0404 - accuracy: 0.9856
#
# Learning rate: 0.0015208066906780005
# Epoch 90/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0403 - accuracy: 0.9862
#
# Learning rate: 0.0015161335468292236
# Epoch 91/120
# 6/6 [==============================] - 3s 442ms/step - loss: 0.0406 - accuracy: 0.9855
#
# Learning rate: 0.0015114747220650315
# Epoch 92/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0361 - accuracy: 0.9876
#
# Learning rate: 0.0015068300999701023
# Epoch 93/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0385 - accuracy: 0.9869
#
# Learning rate: 0.0015021997969597578
# Epoch 94/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0389 - accuracy: 0.9860
#
# Learning rate: 0.001497583813033998
# Epoch 95/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0351 - accuracy: 0.9882
#
# Learning rate: 0.0014929819153621793
# Epoch 96/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0335 - accuracy: 0.9881
#
# Learning rate: 0.0014883941039443016
# Epoch 97/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0335 - accuracy: 0.9886
#
# Learning rate: 0.0014838204951956868
# Epoch 98/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0337 - accuracy: 0.9883
#
# Learning rate: 0.0014792608562856913
# Epoch 99/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0318 - accuracy: 0.9888
#
# Learning rate: 0.0014747153036296368
# Epoch 100/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0308 - accuracy: 0.9894
#
# Learning rate: 0.0014701838372275233
# Epoch 101/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0329 - accuracy: 0.9878
#
# Learning rate: 0.0014656659914180636
# Epoch 102/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0277 - accuracy: 0.9908
#
# Learning rate: 0.001461162231862545
# Epoch 103/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0289 - accuracy: 0.9906
#
# Learning rate: 0.001456672209315002
# Epoch 104/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0279 - accuracy: 0.9901
#
# Learning rate: 0.0014521961566060781
# Epoch 105/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0257 - accuracy: 0.9909
#
# Learning rate: 0.001447733724489808
# Epoch 106/120
# 6/6 [==============================] - 3s 437ms/step - loss: 0.0307 - accuracy: 0.9895
#
# Learning rate: 0.0014432850293815136
# Epoch 107/120
# 6/6 [==============================] - 3s 439ms/step - loss: 0.0328 - accuracy: 0.9889
#
# Learning rate: 0.0014388499548658729
# Epoch 108/120
# 6/6 [==============================] - 3s 441ms/step - loss: 0.0471 - accuracy: 0.9841
#
# Learning rate: 0.0014344286173582077
# Epoch 109/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0377 - accuracy: 0.9871
#
# Learning rate: 0.0014300209004431963
# Epoch 110/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0321 - accuracy: 0.9889
#
# Learning rate: 0.001425626571290195
# Epoch 111/120
# 6/6 [==============================] - 3s 434ms/step - loss: 0.0296 - accuracy: 0.9902
#
# Learning rate: 0.0014212457463145256
# Epoch 112/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0300 - accuracy: 0.9896
#
# Learning rate: 0.00141687854193151
# Epoch 113/120
# 6/6 [==============================] - 3s 436ms/step - loss: 0.0266 - accuracy: 0.9906
#
# Learning rate: 0.0014125246088951826
# Epoch 114/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0286 - accuracy: 0.9901
#
# Learning rate: 0.0014081840636208653
# Epoch 115/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0271 - accuracy: 0.9904
#
# Learning rate: 0.0014038569061085582
# Epoch 116/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0242 - accuracy: 0.9916
#
# Learning rate: 0.001399543136358261
# Epoch 117/120
# 6/6 [==============================] - 3s 440ms/step - loss: 0.0222 - accuracy: 0.9926
#
# Learning rate: 0.0013952425215393305
# Epoch 118/120
# 6/6 [==============================] - 3s 435ms/step - loss: 0.0234 - accuracy: 0.9926
#
# Learning rate: 0.0013909550616517663
# Epoch 119/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0240 - accuracy: 0.9916
#
# Learning rate: 0.0013866808731108904
# Epoch 120/120
# 6/6 [==============================] - 3s 438ms/step - loss: 0.0227 - accuracy: 0.9926
# Training time: 0:06:30.061360

# %%
# Summarize history for accuracy
plt.plot(history.history['accuracy']) 
plt.title('model accuracy') 
plt.ylabel('accuracy') 
plt.xlabel('epoch') 
plt.legend(['train'], loc='upper left') 
plt.show()

# Summarize history for loss
plt.plot(history.history['loss']) 
plt.title('model loss') 
plt.ylabel('loss') 
plt.xlabel('epoch') 
plt.legend(['train'], loc='upper left') 
plt.show()

# %%
# Test accuracy
model.evaluate(X_test, y_test)
# Out:
# 178/178 [==============================] - 1s 3ms/step - loss: 0.0201 - accuracy: 0.9933
# [0.020136039704084396, 0.9933051466941833]

# %%
predicted_classes = model.predict_classes(X_test) 

# Sets the actual test label with the same format
y_test = y_test.argmax(1)

# %%
cm = confusion_matrix(predicted_classes, y_test)
plt.figure(figsize = (13, 8))
sns.heatmap(cm, annot = True, xticklabels = LABELS, yticklabels = LABELS)
