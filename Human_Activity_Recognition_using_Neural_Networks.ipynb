# %% [markdown]
# <a href="https://colab.research.google.com/github/Mario-td/Human-Activity-Recognition-using-Neural-Networks/blob/master/Human_Activity_Recognition_using_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import time
import datetime
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Label of the classes
LABELS = [
    'JUMPING',
    'JUMPING_JACKS',
    'BOXING',
    'WAVING_2HANDS',
    'WAVING_1HAND',
    'CLAPPING_HANDS'
]

# Dataset path
path = '/content/drive/My Drive/Colab Notebooks/RNN-HAR-2D-Pose-database/'

# Load the dataset
data = pd.read_csv(path + '/HAR.csv')

# %%
# Data visualization
data
# Out:
#         Label  Sequence     j0_x     j0_y  ...    j16_x    j16_y    j17_x    j17_y
# 0           0         0  295.914  161.579  ...    0.000    0.000  318.083  161.632
# 1           0         1  295.855  161.600  ...    0.000    0.000  318.024  161.654
# 2           0         2  293.296  161.620  ...    0.000    0.000  316.776  161.679
# 3           0         3  291.978  161.658  ...    0.000    0.000  316.720  161.697
# 4           0         4  288.063  168.120  ...    0.000    0.000  315.402  166.840
# ...       ...       ...      ...      ...  ...      ...      ...      ...      ...
# 908027      5        27  366.269  118.668  ...  340.189  119.987    0.000    0.000
# 908028      5        28  366.290  118.670  ...  340.209  119.993    0.000    0.000
# 908029      5        29  366.263  118.653  ...  340.198  119.966    0.000    0.000
# 908030      5        30  366.268  118.629  ...  340.203  119.970    0.000    0.000
# 908031      5        31  366.257  118.634  ...  340.208  119.964    0.000    0.000
#
# [908032 rows x 38 columns]

# %%
# Get the number of frames per sample
n_steps = max(data['Sequence']) + 1
n_steps
# Out:
# 32

# %%
# Get the labels
Y_ = np.array(data['Label'][0::n_steps][:], dtype=np.int32)
Y_.size
# Out:
# 28376

# %%
# Get the data
X_ = pd.DataFrame.to_numpy(data[data.columns[2:]])
# Split into the number of samples
X_ = np.array(np.split(X_, Y_.size))
X_.shape
# Out:
# (28376, 32, 36)

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_, Y_, test_size=0.2,
                                                    random_state=2)

# %%
print('X_train shape ' + str(X_train.shape))
print('X_test shape ' + str(X_test.shape))
# Out:
# X_train shape (22700, 32, 36)
# X_test shape (5676, 32, 36)

# %%
# Hyperparameters and input data

# Number of input parameters per timestep
n_input = len(X_[0][0])

n_classes = 6

y_train = tf.keras.utils.to_categorical(y_train, n_classes)
y_test = tf.keras.utils.to_categorical(y_test, n_classes)

batch_size = 1024
n_epochs = 120

# %%
# Exponential Decay Learning Rate
initial_learning_rate = 0.002
decay_rate = 0.95
decay_steps = 100
decayed_lr = tf.keras.optimizers.schedules.ExponentialDecay(
              initial_learning_rate, decay_steps, decay_rate, staircase=False)

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        lr = self.model.optimizer._decayed_lr('float32').numpy()
        print('\nLearning rate: {}'.format(lr))

# %%
# Reshape data into time steps of sub-sequences
n_sub_steps, n_length = 4, 8

X_train = X_train.reshape((X_train.shape[0], n_sub_steps, n_length, n_input))
X_test = X_test.reshape((X_test.shape[0], n_sub_steps, n_length, n_input))

# %%
# Define model
model = tf.keras.Sequential()
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu'), input_shape=(None, n_length, n_input)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters=64, kernel_size=3, activation='relu')))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Dropout(0.2)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.MaxPooling1D(pool_size=2)))
model.add(tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten()))
model.add(tf.keras.layers.LSTM(100))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dense(n_classes, activation='softmax'))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=decayed_lr, beta_1=0.9, beta_2=0.999, amsgrad=False)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

t_start = time.time()

history = model.fit(X_train, y_train, shuffle=True, batch_size=batch_size, epochs=n_epochs, callbacks=[MyCustomCallback()])
t_stop = time.time()
print("Training time: " + str(datetime.timedelta(seconds=t_stop - t_start)))
# Out:
# Learning rate: 0.0020000000949949026
# Epoch 1/120
# 23/23 [==============================] - 3s 144ms/step - loss: 1.7517 - accuracy: 0.2324
#
# Learning rate: 0.001976543804630637
# Epoch 2/120
# 23/23 [==============================] - 3s 143ms/step - loss: 1.7089 - accuracy: 0.2736
#
# Learning rate: 0.001953362487256527
# Epoch 3/120
# 23/23 [==============================] - 3s 143ms/step - loss: 1.6102 - accuracy: 0.3271
#
# Learning rate: 0.0019304532324895263
# Epoch 4/120
# 23/23 [==============================] - 3s 144ms/step - loss: 1.4264 - accuracy: 0.4269
#
# Learning rate: 0.0019078126642853022
# Epoch 5/120
# 23/23 [==============================] - 3s 148ms/step - loss: 1.3550 - accuracy: 0.4645
#
# Learning rate: 0.0018854375230148435
# Epoch 6/120
# 23/23 [==============================] - 3s 148ms/step - loss: 1.1884 - accuracy: 0.5294
#
# Learning rate: 0.0018633248982951045
# Epoch 7/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.9313 - accuracy: 0.6308
#
# Learning rate: 0.0018414715304970741
# Epoch 8/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.7281 - accuracy: 0.7029
#
# Learning rate: 0.0018198745092377067
# Epoch 9/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.6471 - accuracy: 0.7254
#
# Learning rate: 0.0017985308077186346
# Epoch 10/120
# 23/23 [==============================] - 3s 143ms/step - loss: 0.5952 - accuracy: 0.7444
#
# Learning rate: 0.0017774372827261686
# Epoch 11/120
# 23/23 [==============================] - 3s 144ms/step - loss: 0.5032 - accuracy: 0.7852
#
# Learning rate: 0.0017565912567079067
# Epoch 12/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.5192 - accuracy: 0.7780
#
# Learning rate: 0.0017359898192808032
# Epoch 13/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.4447 - accuracy: 0.8128
#
# Learning rate: 0.0017156298272311687
# Epoch 14/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.3959 - accuracy: 0.8351
#
# Learning rate: 0.0016955087194219232
# Epoch 15/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.3734 - accuracy: 0.8449
#
# Learning rate: 0.001675623469054699
# Epoch 16/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.3671 - accuracy: 0.8511
#
# Learning rate: 0.001655971514992416
# Epoch 17/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.3598 - accuracy: 0.8534
#
# Learning rate: 0.0016365500632673502
# Epoch 18/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.3437 - accuracy: 0.8611
#
# Learning rate: 0.001617356319911778
# Epoch 19/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.3184 - accuracy: 0.8752
#
# Learning rate: 0.0015983878402039409
# Epoch 20/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.3180 - accuracy: 0.8741
#
# Learning rate: 0.0015796417137607932
# Epoch 21/120
# 23/23 [==============================] - 3s 144ms/step - loss: 0.2482 - accuracy: 0.9056
#
# Learning rate: 0.0015611153794452548
# Epoch 22/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.2432 - accuracy: 0.9070
#
# Learning rate: 0.0015428065089508891
# Epoch 23/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.2847 - accuracy: 0.8927
#
# Learning rate: 0.0015247121918946505
# Epoch 24/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.2261 - accuracy: 0.9152
#
# Learning rate: 0.0015068300999701023
# Epoch 25/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.2182 - accuracy: 0.9187
#
# Learning rate: 0.0014891577884554863
# Epoch 26/120
# 23/23 [==============================] - 4s 159ms/step - loss: 0.1909 - accuracy: 0.9303
#
# Learning rate: 0.0014716926962137222
# Epoch 27/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.1753 - accuracy: 0.9340
#
# Learning rate: 0.0014544326113536954
# Epoch 28/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1666 - accuracy: 0.9412
#
# Learning rate: 0.0014373746234923601
# Epoch 29/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.1785 - accuracy: 0.9350
#
# Learning rate: 0.0014205168699845672
# Epoch 30/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1585 - accuracy: 0.9428
#
# Learning rate: 0.0014038569061085582
# Epoch 31/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1751 - accuracy: 0.9367
#
# Learning rate: 0.0013873924035578966
# Epoch 32/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.1617 - accuracy: 0.9406
#
# Learning rate: 0.0013711208011955023
# Epoch 33/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1218 - accuracy: 0.9567
#
# Learning rate: 0.0013550400035455823
# Epoch 34/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.1173 - accuracy: 0.9605
#
# Learning rate: 0.0013391480315476656
# Epoch 35/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.1408 - accuracy: 0.9494
#
# Learning rate: 0.001323442324064672
# Epoch 36/120
# 23/23 [==============================] - 3s 144ms/step - loss: 0.1163 - accuracy: 0.9601
#
# Learning rate: 0.0013079207856208086
# Epoch 37/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.1215 - accuracy: 0.9563
#
# Learning rate: 0.0012925812043249607
# Epoch 38/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.1460 - accuracy: 0.9478
#
# Learning rate: 0.0012774216011166573
# Epoch 39/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1026 - accuracy: 0.9646
#
# Learning rate: 0.0012624398805201054
# Epoch 40/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0897 - accuracy: 0.9683
#
# Learning rate: 0.0012476338306441903
# Epoch 41/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.1033 - accuracy: 0.9627
#
# Learning rate: 0.0012330013560131192
# Epoch 42/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.1410 - accuracy: 0.9510
#
# Learning rate: 0.0012185405939817429
# Epoch 43/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0927 - accuracy: 0.9685
#
# Learning rate: 0.0012042493326589465
# Epoch 44/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0833 - accuracy: 0.9719
#
# Learning rate: 0.001190125709399581
# Epoch 45/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0960 - accuracy: 0.9672
#
# Learning rate: 0.0011761677451431751
# Epoch 46/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0807 - accuracy: 0.9730
#
# Learning rate: 0.001162373460829258
# Epoch 47/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0686 - accuracy: 0.9755
#
# Learning rate: 0.0011487409938126802
# Epoch 48/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0691 - accuracy: 0.9757
#
# Learning rate: 0.001135268365032971
# Epoch 49/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0739 - accuracy: 0.9738
#
# Learning rate: 0.0011219538282603025
# Epoch 50/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0732 - accuracy: 0.9754
#
# Learning rate: 0.0011087952880188823
# Epoch 51/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0638 - accuracy: 0.9788
#
# Learning rate: 0.0010957912309095263
# Epoch 52/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0572 - accuracy: 0.9797
#
# Learning rate: 0.0010829396778717637
# Epoch 53/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0733 - accuracy: 0.9752
#
# Learning rate: 0.001070238882675767
# Epoch 54/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0634 - accuracy: 0.9778
#
# Learning rate: 0.001057686866261065
# Epoch 55/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0607 - accuracy: 0.9791
#
# Learning rate: 0.001045282231643796
# Epoch 56/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.0630 - accuracy: 0.9786
#
# Learning rate: 0.001033022883348167
# Epoch 57/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0712 - accuracy: 0.9756
#
# Learning rate: 0.0010209075408056378
# Epoch 58/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.0584 - accuracy: 0.9793
#
# Learning rate: 0.0010089342249557376
# Epoch 59/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0537 - accuracy: 0.9807
#
# Learning rate: 0.0009971013059839606
# Epoch 60/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0531 - accuracy: 0.9823
#
# Learning rate: 0.0009854071540758014
# Epoch 61/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0469 - accuracy: 0.9847
#
# Learning rate: 0.0009738501394167542
# Epoch 62/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0464 - accuracy: 0.9841
#
# Learning rate: 0.0009624286903999746
# Epoch 63/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.0512 - accuracy: 0.9824
#
# Learning rate: 0.0009511411772109568
# Epoch 64/120
# 23/23 [==============================] - 3s 144ms/step - loss: 0.0675 - accuracy: 0.9769
#
# Learning rate: 0.0009399860282428563
# Epoch 65/120
# 23/23 [==============================] - 5s 238ms/step - loss: 0.0621 - accuracy: 0.9791
#
# Learning rate: 0.0009289617300964892
# Epoch 66/120
# 23/23 [==============================] - 4s 194ms/step - loss: 0.0509 - accuracy: 0.9830
#
# Learning rate: 0.0009180667111650109
# Epoch 67/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0501 - accuracy: 0.9826
#
# Learning rate: 0.0009072995744645596
# Epoch 68/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0502 - accuracy: 0.9833
#
# Learning rate: 0.0008966585737653077
# Epoch 69/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0681 - accuracy: 0.9766
#
# Learning rate: 0.0008861424867063761
# Epoch 70/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0734 - accuracy: 0.9757
#
# Learning rate: 0.0008757496252655983
# Epoch 71/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0574 - accuracy: 0.9800
#
# Learning rate: 0.0008654787088744342
# Epoch 72/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0483 - accuracy: 0.9839
#
# Learning rate: 0.000855328282341361
# Epoch 73/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0465 - accuracy: 0.9848
#
# Learning rate: 0.000845296832267195
# Epoch 74/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0512 - accuracy: 0.9822
#
# Learning rate: 0.000835383078083396
# Epoch 75/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0423 - accuracy: 0.9864
#
# Learning rate: 0.0008255855645984411
# Epoch 76/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0324 - accuracy: 0.9893
#
# Learning rate: 0.0008159030694514513
# Epoch 77/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0345 - accuracy: 0.9893
#
# Learning rate: 0.0008063340792432427
# Epoch 78/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0344 - accuracy: 0.9885
#
# Learning rate: 0.0007968771969899535
# Epoch 79/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0326 - accuracy: 0.9897
#
# Learning rate: 0.0007875313167460263
# Epoch 80/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0287 - accuracy: 0.9906
#
# Learning rate: 0.0007782950415275991
# Epoch 81/120
# 23/23 [==============================] - 4s 154ms/step - loss: 0.0307 - accuracy: 0.9895
#
# Learning rate: 0.0007691670907661319
# Epoch 82/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0330 - accuracy: 0.9897
#
# Learning rate: 0.0007601461256854236
# Epoch 83/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0516 - accuracy: 0.9827
#
# Learning rate: 0.0007512310403399169
# Epoch 84/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0343 - accuracy: 0.9886
#
# Learning rate: 0.0007424205541610718
# Epoch 85/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0301 - accuracy: 0.9895
#
# Learning rate: 0.0007337133283726871
# Epoch 86/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0307 - accuracy: 0.9901
#
# Learning rate: 0.0007251081988215446
# Epoch 87/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0329 - accuracy: 0.9880
#
# Learning rate: 0.0007166040013544261
# Epoch 88/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0275 - accuracy: 0.9908
#
# Learning rate: 0.0007081995718181133
# Epoch 89/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0381 - accuracy: 0.9873
#
# Learning rate: 0.0006998937460593879
# Epoch 90/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0535 - accuracy: 0.9815
#
# Learning rate: 0.0006916852435097098
# Epoch 91/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0384 - accuracy: 0.9866
#
# Learning rate: 0.0006835730746388435
# Epoch 92/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0435 - accuracy: 0.9863
#
# Learning rate: 0.0006755560170859098
# Epoch 93/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0364 - accuracy: 0.9879
#
# Learning rate: 0.0006676330231130123
# Epoch 94/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0297 - accuracy: 0.9901
#
# Learning rate: 0.0006598028703592718
# Epoch 95/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0269 - accuracy: 0.9913
#
# Learning rate: 0.0006520646275021136
# Epoch 96/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0261 - accuracy: 0.9919
#
# Learning rate: 0.0006444171885959804
# Epoch 97/120
# 23/23 [==============================] - 3s 149ms/step - loss: 0.0216 - accuracy: 0.9931
#
# Learning rate: 0.000636859389487654
# Epoch 98/120
# 23/23 [==============================] - 4s 152ms/step - loss: 0.0248 - accuracy: 0.9917
#
# Learning rate: 0.0006293901242315769
# Epoch 99/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0263 - accuracy: 0.9911
#
# Learning rate: 0.0006220085779204965
# Epoch 100/120
# 23/23 [==============================] - 4s 153ms/step - loss: 0.0242 - accuracy: 0.9920
#
# Learning rate: 0.0006147135864011943
# Epoch 101/120
# 23/23 [==============================] - 4s 152ms/step - loss: 0.0200 - accuracy: 0.9937
#
# Learning rate: 0.000607504160143435
# Epoch 102/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0202 - accuracy: 0.9937
#
# Learning rate: 0.000600379251409322
# Epoch 103/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0295 - accuracy: 0.9900
#
# Learning rate: 0.0005933379288762808
# Epoch 104/120
# 23/23 [==============================] - 3s 151ms/step - loss: 0.0207 - accuracy: 0.9930
#
# Learning rate: 0.0005863791448064148
# Epoch 105/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0180 - accuracy: 0.9942
#
# Learning rate: 0.0005795020260848105
# Epoch 106/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0166 - accuracy: 0.9947
#
# Learning rate: 0.0005727055249735713
# Epoch 107/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0185 - accuracy: 0.9940
#
# Learning rate: 0.0005659887683577836
# Epoch 108/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0208 - accuracy: 0.9930
#
# Learning rate: 0.0005593507667072117
# Epoch 109/120
# 23/23 [==============================] - 3s 148ms/step - loss: 0.0204 - accuracy: 0.9931
#
# Learning rate: 0.0005527905886992812
# Epoch 110/120
# 23/23 [==============================] - 3s 152ms/step - loss: 0.0229 - accuracy: 0.9926
#
# Learning rate: 0.0005463074194267392
# Epoch 111/120
# 23/23 [==============================] - 3s 150ms/step - loss: 0.0192 - accuracy: 0.9932
#
# Learning rate: 0.0005399002111516893
# Epoch 112/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0190 - accuracy: 0.9938
#
# Learning rate: 0.0005335682071745396
# Epoch 113/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0192 - accuracy: 0.9935
#
# Learning rate: 0.0005273104761727154
# Epoch 114/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0173 - accuracy: 0.9944
#
# Learning rate: 0.0005211261450313032
# Epoch 115/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0228 - accuracy: 0.9922
#
# Learning rate: 0.0005150142242200673
# Epoch 116/120
# 23/23 [==============================] - 3s 146ms/step - loss: 0.0343 - accuracy: 0.9884
#
# Learning rate: 0.0005089740152470767
# Epoch 117/120
# 23/23 [==============================] - 3s 144ms/step - loss: 0.0410 - accuracy: 0.9853
#
# Learning rate: 0.0005030047614127398
# Epoch 118/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0226 - accuracy: 0.9930
#
# Learning rate: 0.0004971054149791598
# Epoch 119/120
# 23/23 [==============================] - 3s 147ms/step - loss: 0.0184 - accuracy: 0.9944
#
# Learning rate: 0.000491275277454406
# Epoch 120/120
# 23/23 [==============================] - 3s 145ms/step - loss: 0.0165 - accuracy: 0.9942
# Training time: 0:07:16.271090

# %%
# Summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# Summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
# Test accuracy
model.evaluate(X_test, y_test)
# Out:
# 178/178 [==============================] - 1s 4ms/step - loss: 0.0197 - accuracy: 0.9924
# [0.019743310287594795, 0.9924242496490479]

# %%
predicted_classes = model.predict_classes(X_test)

# Sets the actual test label with the same format
y_test = y_test.argmax(1)

# %%
cm = confusion_matrix(predicted_classes, y_test)
plt.figure(figsize=(13, 8))
sns.heatmap(cm, annot=True, xticklabels=LABELS, yticklabels=LABELS)
